# %%
import numpy as np

# %%
def cal(x):
    return np.sqrt(x*(1-x)) / x
cal(0.0354)
# Out:
# 5.220017966503705

# %%
cal(0.8)
# Out:
# 0.49999999999999994

# %%
cal(0.0031)
# Out:
# 17.932669772270117

# %%
import matplotlib.pyplot as plt

# %%
x = [7, 8, 9, 10, 11, 12, 13]
y = [4, 5, 6,6,6,7,7]

# %%
plt.figure(figsize=(15,10))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Number of stores',fontsize=15)
plt.ylabel('Number of operators',fontsize=15)
plt.scatter(x,y)
plt.show()
